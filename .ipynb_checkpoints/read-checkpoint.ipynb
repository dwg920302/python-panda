# %%
import pandas as pd
import numpy as np
import string
import random

df = pd.DataFrame(np.random.randint(0, 100, size=(10, 4)),
             index=list((''.join(random.choice(string.ascii_letters) for i in range(5))) for i in range(10)),
             columns=['국어', '영어', '수학', '사회']
            )
df
# Out:
#        국어  영어  수학  사회
# oemfv  61  97  69  68
# kPyir  75  66  10  25
# WdJsA  18  51  22  41
# aGjQZ  92  22   4   4
# oJLNk  61  36  91  52
# cIHcS   7  75  40  14
# bNYcq  17  11  10  37
# aHnAV  80  74   8  10
# UaigJ  83  97  24   6
# bHxYb  42  95  70  93

# %%
df.loc[:, ['국어', '영어']]
# Out:
#        국어  영어
# FmwfW  53  78
# NYIch  96  38
# dXULk  89  89
# FeipS  60  70
# KfkuD  77  48
# DfkMI  89  14
# Njehx  30  64
# NcLvR  63  26
# mkenx   6  77
# nWRmB  13  42

# %%
# 과학 추가. 그에 따라 과학에도 점수 입력
# df['과학'] = [np.random.randint(100 + 1) for i in range(10)]
df.loc[:, '과학'] = pd.Series([np.random.randint(100 + 1) for i in range(10)], index=df.index)
df
# Out:
#        국어  영어  수학  사회  과학   총합  개인 총합
# oemfv  61  97  69  68  28  339    339
# kPyir  75  66  10  25  18  275    275
# WdJsA  18  51  22  41   5  177    177
# aGjQZ  92  22   4   4  49  186    186
# oJLNk  61  36  91  52  85  272    272
# cIHcS   7  75  40  14  71  178    178
# bNYcq  17  11  10  37  64   95     95
# aHnAV  80  74   8  10  12  240    240
# UaigJ  83  97  24   6  74  281    281
# bHxYb  42  95  70  93  45  322    322

# %%
# 각 학생들의 점수의 총합을 표현하는 컬럼 추가
df['개인 총합'] = np.sum(df.loc[:, '국어': '과학'], axis=1)
df
# Out:
#        국어  영어  수학  사회  과학   총합  개인 총합
# oemfv  61  97  69  68  28  339    323
# kPyir  75  66  10  25  18  275    194
# WdJsA  18  51  22  41   5  177    137
# aGjQZ  92  22   4   4  49  186    171
# oJLNk  61  36  91  52  85  272    325
# cIHcS   7  75  40  14  71  178    207
# bNYcq  17  11  10  37  64   95    139
# aHnAV  80  74   8  10  12  240    184
# UaigJ  83  97  24   6  74  281    284
# bHxYb  42  95  70  93  45  322    345

# %%
df.insert(11, '과목 총합', np.random.randint(100 + 1))
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-057b511888aa> in <module>
# ----> 1 df.insert(11, '과목 총합', np.random.randint(100 + 1))
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1218             self._blknos = np.append(self._blknos, len(self.blocks))
#    1219         else:
# -> 1220             self._blklocs = np.insert(self._blklocs, loc, 0)
#    1221             self._blknos = np.insert(self._blknos, loc, len(self.blocks))
#    1222
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in insert(arr, obj, values, axis)
#    4630         index = indices.item()
#    4631         if index < -N or index > N:
# -> 4632             raise IndexError(
#    4633                 "index %i is out of bounds for axis %i with "
#    4634                 "size %i" % (obj, axis, N))
#
# IndexError: index 11 is out of bounds for axis 0 with size 7
